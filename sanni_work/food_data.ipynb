# %%
# !pip install CFEDemands --upgrade
# !pip install xarray
# Out:
# Requirement already up-to-date: CFEDemands in /Users/sannidhi/anaconda3/lib/python3.7/site-packages (0.1.6.6)
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: xarray in /Users/sannidhi/anaconda3/lib/python3.7/site-packages (0.12.0)
# Requirement already satisfied: pandas>=0.19.2 in /Users/sannidhi/anaconda3/lib/python3.7/site-packages (from xarray) (0.23.4)
# Requirement already satisfied: numpy>=1.12 in /Users/sannidhi/anaconda3/lib/python3.7/site-packages (from xarray) (1.15.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/sannidhi/anaconda3/lib/python3.7/site-packages (from pandas>=0.19.2->xarray) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /Users/sannidhi/anaconda3/lib/python3.7/site-packages (from pandas>=0.19.2->xarray) (2018.5)
# Requirement already satisfied: six>=1.5 in /Users/sannidhi/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas>=0.19.2->xarray) (1.11.0)
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import cfe
import pandas as pd
import numpy as np
import random
import xarray as xr

import warnings
warnings.filterwarnings('ignore')

from IPython.display import display
pd.options.display.max_columns = None

# %%
expends = pd.read_csv('data/fs_avg_expend.csv')
expends = expends.append([expends]*2,ignore_index=False).sort_values('Unnamed: 0', ascending=True)
expends = expends.rename(columns={'Unnamed: 0': 'category'}).set_index('category') / 3
expends
# Out:
#                   mean     ratio
# category
# alcbev        1.614129  0.020876
# alcbev        1.614129  0.020876
# alcbev        1.614129  0.020876
# bakery        2.635406  0.034085
# bakery        2.635406  0.034085
# bakery        2.635406  0.034085
# beef          1.950369  0.025225
# beef          1.950369  0.025225
# beef          1.950369  0.025225
# cereal        1.364160  0.017643
# cereal        1.364160  0.017643
# cereal        1.364160  0.017643
# eggs          0.358410  0.004636
# eggs          0.358410  0.004636
# eggs          0.358410  0.004636
# fresh_fruit   2.702366  0.034951
# fresh_fruit   2.702366  0.034951
# fresh_fruit   2.702366  0.034951
# fresh_veg     2.177602  0.028164
# fresh_veg     2.177602  0.028164
# fresh_veg     2.177602  0.028164
# milk          1.094975  0.014162
# milk          1.094975  0.014162
# milk          1.094975  0.014162
# non_alc_bevs  3.312568  0.042843
# non_alc_bevs  3.312568  0.042843
# non_alc_bevs  3.312568  0.042843
# oils          0.809856  0.010474
# oils          0.809856  0.010474
# oils          0.809856  0.010474
# othdairy      1.738234  0.022481
# othdairy      1.738234  0.022481
# othdairy      1.738234  0.022481
# othmeat       0.934504  0.012086
# othmeat       0.934504  0.012086
# othmeat       0.934504  0.012086
# pork          1.325168  0.017139
# pork          1.325168  0.017139
# pork          1.325168  0.017139
# poultry       2.799477  0.032660
# poultry       2.799477  0.032660
# poultry       2.799477  0.032660
# proc_veg      1.049941  0.013579
# proc_veg      1.049941  0.013579
# proc_veg      1.049941  0.013579
# procfruit     0.676176  0.008745
# procfruit     0.676176  0.008745
# procfruit     0.676176  0.008745
# seafood       0.864718  0.011184
# seafood       0.864718  0.011184
# seafood       0.864718  0.011184
# sweets        1.164238  0.015058
# sweets        1.164238  0.015058
# sweets        1.164238  0.015058

# %%
foods = pd.read_csv('data/us_foods.csv')
foods = foods.set_index('food').drop(columns=['Unnamed: 9'])
foods = foods[['category','quantity','units','price','ndb']]
foods['expend'] = expends['mean'].tolist()
foods['qty_purchased'] = (foods['expend'] / foods['price'] * foods['quantity']).tolist()
foods.to_csv('data/us_foods.csv')
